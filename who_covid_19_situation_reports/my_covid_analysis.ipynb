# %%
import pandas as pd

# %% [markdown]
# ### <font color='DodgerBlue'> Import WHO CSV for COVID data from 1/21 to 3/5</font>

# %%
df = pd.read_csv('/Users/jiffy/projects/covid_2019/COVID-19/who_covid_19_situation_reports/who_covid_19_sit_rep_time_series/who_covid_19_sit_rep_time_series.csv')

# %% [markdown]
# ### <font color='DodgerBlue'>Inspect Data</font>

# %%
df.index
# Out:
# RangeIndex(start=0, stop=123, step=1)

# %%
df.head()
# Out:
#   Province/States    Country/Region              WHO region  1/21/2020  \
# 0       Confirmed          Globally                     NaN      282.0
# 1       Confirmed             China  Western Pacific Region      278.0
# 2       Confirmed  Outside of China                     NaN        4.0
# 3          Deaths             China  Western Pacific Region        NaN
# 4          Hubei              China  Western Pacific Region      258.0
#
#    1/22/2020  1/23/2020  1/24/2020  1/25/2020  1/26/2020  1/27/2020  ...  \
# 0      314.0      581.0      846.0     1320.0     2014.0     2798.0  ...
# 1      309.0      571.0      830.0     1297.0     1985.0     2741.0  ...
# 2        5.0       10.0       16.0       23.0       29.0       57.0  ...
# 3        NaN        NaN        NaN        NaN        NaN       80.0  ...
# 4      270.0      375.0      375.0        NaN        NaN        NaN  ...
#
#    2/29/2020  3/1/2020  3/2/2020  3/3/2020  3/4/2020  3/5/2020  Unnamed: 48  \
# ...

# %% [markdown]
# ### <font color='DodgerBlue'>Drop Columns</font>

# %%
df.drop(columns = ['Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51'], inplace=True)

# %%
df.head()
# Out:
#   Province/States    Country/Region              WHO region  1/21/2020  \
# 0       Confirmed          Globally                     NaN      282.0
# 1       Confirmed             China  Western Pacific Region      278.0
# 2       Confirmed  Outside of China                     NaN        4.0
# 3          Deaths             China  Western Pacific Region        NaN
# 4          Hubei              China  Western Pacific Region      258.0
#
#    1/22/2020  1/23/2020  1/24/2020  1/25/2020  1/26/2020  1/27/2020  ...  \
# 0      314.0      581.0      846.0     1320.0     2014.0     2798.0  ...
# 1      309.0      571.0      830.0     1297.0     1985.0     2741.0  ...
# 2        5.0       10.0       16.0       23.0       29.0       57.0  ...
# 3        NaN        NaN        NaN        NaN        NaN       80.0  ...
# 4      270.0      375.0      375.0        NaN        NaN        NaN  ...
#
#    2/25/2020  2/26/2020  2/27/2020  2/28/2020  2/29/2020  3/1/2020  3/2/2020  \
# ...

# %% [markdown]
# ### <font color='DodgerBlue'>Rename Columns for ease of use</font>

# %%
df.rename(columns={'Province/States': 'province_or_states', 'Country/Region': 'country_or_region', 'WHO region': 'who_region'}, inplace=True)

# %% [markdown]
# ### <font color='DodgerBlue'>Use melt method to change data from wide to long format</font>

# %%
df = df.melt(id_vars=['province_or_states', 'country_or_region', 'who_region'])

# %%
df.head()
# Out:
#   province_or_states country_or_region              who_region   variable  \
# 0          Confirmed          Globally                     NaN  1/21/2020
# 1          Confirmed             China  Western Pacific Region  1/21/2020
# 2          Confirmed  Outside of China                     NaN  1/21/2020
# 3             Deaths             China  Western Pacific Region  1/21/2020
# 4             Hubei              China  Western Pacific Region  1/21/2020
#
#    value
# 0  282.0
# 1  278.0
# 2    4.0
# 3    NaN
# 4  258.0

# %%
df.rename(columns={'variable': 'date', 'value': 'amount'}, inplace=True)

# %%
df.head()
# Out:
#   province_or_states country_or_region              who_region       date  \
# 0          Confirmed          Globally                     NaN  1/21/2020
# 1          Confirmed             China  Western Pacific Region  1/21/2020
# 2          Confirmed  Outside of China                     NaN  1/21/2020
# 3             Deaths             China  Western Pacific Region  1/21/2020
# 4             Hubei              China  Western Pacific Region  1/21/2020
#
#    amount
# 0   282.0
# 1   278.0
# 2     4.0
# 3     NaN
# 4   258.0

# %%
china = df[(df.country_or_region == 'China') & (df.province_or_states == 'Deaths')]

# %%
china
# Out:
#      province_or_states country_or_region              who_region       date  \
# 3                Deaths             China  Western Pacific Region  1/21/2020
# 126              Deaths             China  Western Pacific Region  1/22/2020
# 249              Deaths             China  Western Pacific Region  1/23/2020
# 372              Deaths             China  Western Pacific Region  1/24/2020
# 495              Deaths             China  Western Pacific Region  1/25/2020
# 618              Deaths             China  Western Pacific Region  1/26/2020
# 741              Deaths             China  Western Pacific Region  1/27/2020
# 864              Deaths             China  Western Pacific Region  1/28/2020
# 987              Deaths             China  Western Pacific Region  1/29/2020
# 1110             Deaths             China  Western Pacific Region  1/30/2020
# 1233             Deaths             China  Western Pacific Region  1/31/2020
# ...

# %%
df.set_index(keys='date', inplace=True)

# %%
# df.drop(df[df['date']=='Total'].index,inplace=True)

# %%
df.index=pd.to_datetime(df.index,format='%m/%d/%Y')

# %%
df
# Out:
#                              province_or_states  \
# date
# 2020-01-21                            Confirmed
# 2020-01-21                            Confirmed
# 2020-01-21                            Confirmed
# 2020-01-21                               Deaths
# 2020-01-21                               Hubei
# 2020-01-21                            Guangdong
# 2020-01-21                                Henan
# 2020-01-21                             Zhejiang
# 2020-01-21                                Hunan
# 2020-01-21                                Anhui
# 2020-01-21                              Jiangxi
# 2020-01-21                             Shandong
# 2020-01-21                              Jiangsu
# 2020-01-21                            Chongqing
# 2020-01-21                              Sichuan
# 2020-01-21                         Heilongjiang
# 2020-01-21                              Beijing
# 2020-01-21                             Shanghai
# ...

# %%
df_march_5 = df[df.index == '2020-03-05']

# %%
df_march_5
# Out:
#                              province_or_states  \
# date
# 2020-03-05                            Confirmed
# 2020-03-05                            Confirmed
# 2020-03-05                            Confirmed
# 2020-03-05                               Deaths
# 2020-03-05                               Hubei
# 2020-03-05                            Guangdong
# 2020-03-05                                Henan
# 2020-03-05                             Zhejiang
# 2020-03-05                                Hunan
# 2020-03-05                                Anhui
# 2020-03-05                              Jiangxi
# 2020-03-05                             Shandong
# 2020-03-05                              Jiangsu
# 2020-03-05                            Chongqing
# 2020-03-05                              Sichuan
# 2020-03-05                         Heilongjiang
# 2020-03-05                              Beijing
# 2020-03-05                             Shanghai
# ...
